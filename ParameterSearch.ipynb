# %%
# %load_ext autoreload
# %autoreload 2

# %%
import worker

results = worker.runworkers(num_params=10, max_iters=500, num_runs=5, max_workers=2, test_state={'k': 2, 'z':1})
# Out:
# num_params 10 max_workers 2
# ...

# %%
import matplotlib.pyplot as plt
import pprint

# %matplotlib inline

for r in results:
    pprint.pprint(r[0])
    plt.hist(r[1])
    plt.show()
# Out:
# {'naf': {'learningParameters': {'compress': False,
#                                 'discount': 0.75,
#                                 'learning_rate': 0.001},
#          'nnpParameters': {'hidden_layers': [25, 25],
#                            'nonlinearity': <function relu at 0x7f7ae3b8a398>},
#          'nnqParameters': {'hidden_layers': [10, 10],
#                            'nonlinearity': <function relu at 0x7f7ae3b8a398>},
#          'nnvParameters': {'hidden_layers': [10, 10],
#                            'nonlinearity': <function relu at 0x7f7ae3b8a398>}},
#  'strat': {'hi': 1.7, 'lo': 0.90000000000000002, 'max_iters': 40}}
# {'naf': {'learningParameters': {'compress': False,
#                                 'discount': 0.94999999999999996,
#                                 'learning_rate': 0.01},
#          'nnpParameters': {'hidden_layers': [],
#                            'nonlinearity': <function tanh at 0x7f7ae3d13cf8>},
# ...

# %%
import tensorflow as tf

results = [({'strat': {'lo': 0.80000000000000004, 'hi': 1.5, 'max_iters': 40}, 'naf': {'nnqParameters': {'hidden_layers': [100, 100], 'nonlinearity': tf.nn.relu }, 'learningParameters': {'discount': 0.75, 'learning_rate': 0.0001, 'compress': False}, 'nnpParameters': {'hidden_layers': [], 'nonlinearity': tf.nn.relu }, 'nnvParameters': {'hidden_layers': [100], 'nonlinearity': tf.nn.tanh }}}, [-1.1216988337753377, -2.807605313614143, -2.331746637218542,  -20001.39503197856]), ({'strat': {'lo': 0.90000000000000002, 'hi': 1.2, 'max_iters': 40}, 'naf': {'nnqParameters': {'hidden_layers': [10, 10], 'nonlinearity': tf.nn.relu }, 'learningParameters': {'discount': 0.75, 'learning_rate': 0.0001, 'compress': False}, 'nnpParameters': {'hidden_layers': [5], 'nonlinearity': tf.nn.relu }, 'nnvParameters': {'hidden_layers': [400], 'nonlinearity': tf.nn.relu }}}, [-3.510415895705441, -2.0029700986168195, -3.2811196495341695, -1.0281457415115545, -1.1601456343931904]), ({'strat': {'lo': 0.5, 'hi': 1.2, 'max_iters': 40}, 'naf': {'nnqParameters': {'hidden_layers': [5], 'nonlinearity': tf.nn.relu }, 'learningParameters': {'discount': 0.98999999999999999, 'learning_rate': 0.0001, 'compress': True}, 'nnpParameters': {'hidden_layers': [25, 25], 'nonlinearity': tf.nn.relu }, 'nnvParameters': {'hidden_layers': [100, 100], 'nonlinearity': tf.nn.relu }}}, [-999999, -999999, -999999, 0.9062266438425489, -999999]), ({'strat': {'lo': 0.80000000000000004, 'hi': 1.1000000000000001, 'max_iters': 40}, 'naf': {'nnqParameters': {'hidden_layers': [400], 'nonlinearity': tf.nn.relu }, 'learningParameters': {'discount': 0.75, 'learning_rate': 0.01, 'compress': False}, 'nnpParameters': {'hidden_layers': [], 'nonlinearity': tf.nn.relu }, 'nnvParameters': {'hidden_layers': [200], 'nonlinearity': tf.nn.relu }}}, [-999999, -19999.155253414403, -780000.241832823, -999999, -0.6357947667622733]), ({'strat': {'lo': 0.80000000000000004, 'hi': 1.7, 'max_iters': 40}, 'naf': {'nnqParameters': {'hidden_layers': [5], 'nonlinearity': tf.nn.relu }, 'learningParameters': {'discount': 0.98999999999999999, 'learning_rate': 0.001, 'compress': False}, 'nnpParameters': {'hidden_layers': [25], 'nonlinearity': tf.nn.relu }, 'nnvParameters': {'hidden_layers': [100, 100, 100], 'nonlinearity': tf.nn.relu }}}, [   -1.7043253827080371, 0.05776341904773832]), ({'strat': {'lo': 0.80000000000000004, 'hi': 1.2, 'max_iters': 40}, 'naf': {'nnqParameters': {'hidden_layers': [200, 200], 'nonlinearity': tf.nn.tanh }, 'learningParameters': {'discount': 0.94999999999999996, 'learning_rate': 0.01, 'compress': False}, 'nnpParameters': {'hidden_layers': [10], 'nonlinearity': tf.nn.relu }, 'nnvParameters': {'hidden_layers': [100, 100], 'nonlinearity': tf.nn.relu }}}, [-399999.72526150435, -60001.309131891074, 0.412148811304565, -59999.86117842039, -39999.224345725284]), ({'strat': {'lo': 0.90000000000000002, 'hi': 1.1000000000000001, 'max_iters': 40}, 'naf': {'nnqParameters': {'hidden_layers': [100], 'nonlinearity': tf.nn.relu }, 'learningParameters': {'discount': 0.75, 'learning_rate': 0.0001, 'compress': False}, 'nnpParameters': {'hidden_layers': [10], 'nonlinearity': tf.nn.tanh }, 'nnvParameters': {'hidden_layers': [50], 'nonlinearity': tf.nn.tanh }}}, [-3.123476680180187, -20001.857665572395, -20000.952337069888, -20002.584835975482, -2.183913055500037]), ({'strat': {'lo': 0.90000000000000002, 'hi': 1.1000000000000001, 'max_iters': 40}, 'naf': {'nnqParameters': {'hidden_layers': [10, 10, 10], 'nonlinearity': tf.nn.relu }, 'learningParameters': {'discount': 0.94999999999999996, 'learning_rate': 0.0001, 'compress': False}, 'nnpParameters': {'hidden_layers': [10], 'nonlinearity': tf.nn.tanh }, 'nnvParameters': {'hidden_layers': [5], 'nonlinearity': tf.nn.tanh }}}, [-60002.24901015814, -0.3811056621862762, -1.9900092559857836, -3.4972929686161836, -5.655197211616046]), ({'strat': {'lo': 0.5, 'hi': 1.2, 'max_iters': 40}, 'naf': {'nnqParameters': {'hidden_layers': [5], 'nonlinearity': tf.nn.tanh }, 'learningParameters': {'discount': 0.94999999999999996, 'learning_rate': 0.002, 'compress': False}, 'nnpParameters': {'hidden_layers': [10], 'nonlinearity': tf.nn.relu }, 'nnvParameters': {'hidden_layers': [10, 10, 10], 'nonlinearity': tf.nn.tanh }}}, [-1.054791511574846, -3.066148036293917,  -0.659840881630089, -20002.023752275294]), ({'strat': {'lo': 0.69999999999999996, 'hi': 1.7, 'max_iters': 40}, 'naf': {'nnqParameters': {'hidden_layers': [10, 10], 'nonlinearity': tf.nn.tanh }, 'learningParameters': {'discount': 0.98999999999999999, 'learning_rate': 0.01, 'compress': True}, 'nnpParameters': {'hidden_layers': [], 'nonlinearity': tf.nn.tanh }, 'nnvParameters': {'hidden_layers': [200], 'nonlinearity': tf.nn.tanh }}}, [-4.4018519050979785, -3.009763737350612, -0.8533484812706846, -9.696558849264282, -3.0723404011702447]), ({'strat': {'lo': 0.90000000000000002, 'hi': 1.2, 'max_iters': 40}, 'naf': {'nnqParameters': {'hidden_layers': [200, 200], 'nonlinearity': tf.nn.tanh }, 'learningParameters': {'discount': 0.75, 'learning_rate': 0.002, 'compress': False}, 'nnpParameters': {'hidden_layers': [5, 5], 'nonlinearity': tf.nn.relu }, 'nnvParameters': {'hidden_layers': [400], 'nonlinearity': tf.nn.relu }}}, [ -20001.932357740512, -20000.18814342517, -0.04668885504708745, -1.1260980673303265]), ({'strat': {'lo': 0.69999999999999996, 'hi': 1.2, 'max_iters': 40}, 'naf': {'nnqParameters': {'hidden_layers': [200, 200], 'nonlinearity': tf.nn.tanh }, 'learningParameters': {'discount': 0.75, 'learning_rate': 0.001, 'compress': False}, 'nnpParameters': {'hidden_layers': [10], 'nonlinearity': tf.nn.tanh }, 'nnvParameters': {'hidden_layers': [100, 100, 100], 'nonlinearity': tf.nn.tanh }}}, [-1.6621538119852992, -2.060639531782939, -2.0545693494213584, -20002.652691177285, -2.7739174153932167]), ({'strat': {'lo': 0.90000000000000002, 'hi': 1.7, 'max_iters': 40}, 'naf': {'nnqParameters': {'hidden_layers': [10, 10], 'nonlinearity': tf.nn.relu }, 'learningParameters': {'discount': 0.94999999999999996, 'learning_rate': 0.0001, 'compress': False}, 'nnpParameters': {'hidden_layers': [], 'nonlinearity': tf.nn.relu }, 'nnvParameters': {'hidden_layers': [5], 'nonlinearity': tf.nn.tanh }}}, [-1.2066521960816834, -0.1250973151388378, -3.3613665686338434, -0.3582978219536688, -1.4932340083508722]), ({'strat': {'lo': 0.80000000000000004, 'hi': 1.7, 'max_iters': 40}, 'naf': {'nnqParameters': {'hidden_layers': [100, 100], 'nonlinearity': tf.nn.tanh }, 'learningParameters': {'discount': 0.75, 'learning_rate': 0.01, 'compress': False}, 'nnpParameters': {'hidden_layers': [10], 'nonlinearity': tf.nn.relu }, 'nnvParameters': {'hidden_layers': [10, 10, 10], 'nonlinearity': tf.nn.tanh }}}, [0.08723085392439422, -19999.39787607353, 0.36060549583984725, -39999.99017156873, -60003.406879210605]), ({'strat': {'lo': 0.5, 'hi': 1.2, 'max_iters': 40}, 'naf': {'nnqParameters': {'hidden_layers': [200, 200], 'nonlinearity': tf.nn.tanh }, 'learningParameters': {'discount': 0.75, 'learning_rate': 0.01, 'compress': True}, 'nnpParameters': {'hidden_layers': [], 'nonlinearity': tf.nn.relu }, 'nnvParameters': {'hidden_layers': [200, 200], 'nonlinearity': tf.nn.tanh }}}, [-999999, -999999, -999999, -999999, -999999]), ({'strat': {'lo': 0.5, 'hi': 1.7, 'max_iters': 40}, 'naf': {'nnqParameters': {'hidden_layers': [100], 'nonlinearity': tf.nn.tanh }, 'learningParameters': {'discount': 0.98999999999999999, 'learning_rate': 0.01, 'compress': True}, 'nnpParameters': {'hidden_layers': [25], 'nonlinearity': tf.nn.tanh }, 'nnvParameters': {'hidden_layers': [1000], 'nonlinearity': tf.nn.relu }}}, [-4.204025977004173, -999999, -1.9314059979917466, -5.055900208517382, -999999]), ({'strat': {'lo': 0.80000000000000004, 'hi': 1.7, 'max_iters': 40}, 'naf': {'nnqParameters': {'hidden_layers': [1000], 'nonlinearity': tf.nn.tanh }, 'learningParameters': {'discount': 0.94999999999999996, 'learning_rate': 0.0001, 'compress': True}, 'nnpParameters': {'hidden_layers': [25, 25], 'nonlinearity': tf.nn.tanh }, 'nnvParameters': {'hidden_layers': [100, 100], 'nonlinearity': tf.nn.relu }}}, [-999999, -999999, -3.0226435329047687, -999999, -999999]), ({'strat': {'lo': 0.5, 'hi': 1.2, 'max_iters': 40}, 'naf': {'nnqParameters': {'hidden_layers': [100, 100, 100], 'nonlinearity': tf.nn.tanh }, 'learningParameters': {'discount': 0.75, 'learning_rate': 0.0001, 'compress': True}, 'nnpParameters': {'hidden_layers': [5, 5], 'nonlinearity': tf.nn.tanh }, 'nnvParameters': {'hidden_layers': [100, 100], 'nonlinearity': tf.nn.tanh }}}, [-3.1192766747405263, -3.195725722505442, -3.484002339888848, -60003.74707708899, -999999]), ({'strat': {'lo': 0.90000000000000002, 'hi': 1.2, 'max_iters': 40}, 'naf': {'nnqParameters': {'hidden_layers': [100, 100], 'nonlinearity': tf.nn.tanh }, 'learningParameters': {'discount': 0.75, 'learning_rate': 0.01, 'compress': True}, 'nnpParameters': {'hidden_layers': [25], 'nonlinearity': tf.nn.tanh }, 'nnvParameters': {'hidden_layers': [100, 100], 'nonlinearity': tf.nn.relu }}}, [-999999, -999999, -1.243024562130849, -999999, -999999]), ({'strat': {'lo': 0.80000000000000004, 'hi': 1.5, 'max_iters': 40}, 'naf': {'nnqParameters': {'hidden_layers': [1000], 'nonlinearity': tf.nn.tanh }, 'learningParameters': {'discount': 0.98999999999999999, 'learning_rate': 0.001, 'compress': False}, 'nnpParameters': {'hidden_layers': [5, 5], 'nonlinearity': tf.nn.relu }, 'nnvParameters': {'hidden_layers': [100], 'nonlinearity': tf.nn.tanh }}}, [-2.1216401252238133, -2.920275967439116, -680000.8601711467,  -20002.279866950088])]

# %%
import matplotlib.pyplot as plt
import pprint
import numpy as np
results = [({'strat': {'lo': 0.80000000000000004, 'hi': 1.1000000000000001, 'max_iters': 40}, 'naf': {'nnqParameters': {'hidden_layers': [50], 'nonlinearity': tf.nn.tanh}, 'learningParameters': {'discount': 0.94999999999999996, 'learning_rate': 0.01, 'compress': False}, 'nnpParameters': {'hidden_layers': [25], 'nonlinearity': tf.nn.relu}, 'nnvParameters': {'hidden_layers': [100, 100, 100], 'nonlinearity': tf.nn.relu}}}, [-25.121049051772253, -22.613861868096734, -22.29707011358895, -22.2570849722395, -22.3387359313289]), ({'strat': {'lo': 0.80000000000000004, 'hi': 1.7, 'max_iters': 40}, 'naf': {'nnqParameters': {'hidden_layers': [400], 'nonlinearity': tf.nn.tanh}, 'learningParameters': {'discount': 0.98999999999999999, 'learning_rate': 0.001, 'compress': True}, 'nnpParameters': {'hidden_layers': [25, 25], 'nonlinearity': tf.nn.tanh}, 'nnvParameters': {'hidden_layers': [10, 10, 10], 'nonlinearity': tf.nn.relu}}}, [-999999, -999999, -999999, -999999, -999999]), ({'strat': {'lo': 0.69999999999999996, 'hi': 1.2, 'max_iters': 40}, 'naf': {'nnqParameters': {'hidden_layers': [200], 'nonlinearity': tf.nn.relu}, 'learningParameters': {'discount': 0.75, 'learning_rate': 0.01, 'compress': True}, 'nnpParameters': {'hidden_layers': [], 'nonlinearity': tf.nn.relu}, 'nnvParameters': {'hidden_layers': [50], 'nonlinearity': tf.nn.tanh}}}, [-999999, -999999, -999999, -999999, -999999]), ({'strat': {'lo': 0.80000000000000004, 'hi': 1.5, 'max_iters': 40}, 'naf': {'nnqParameters': {'hidden_layers': [100, 100], 'nonlinearity': tf.nn.relu}, 'learningParameters': {'discount': 0.98999999999999999, 'learning_rate': 0.01, 'compress': False}, 'nnpParameters': {'hidden_layers': [10], 'nonlinearity': tf.nn.relu}, 'nnvParameters': {'hidden_layers': [400], 'nonlinearity': tf.nn.relu}}}, [-22.183042814508877, -22.881484449812692, -19.329813640014795, -21.98340268341589, -21.047027482082388]), ({'strat': {'lo': 0.5, 'hi': 1.1000000000000001, 'max_iters': 40}, 'naf': {'nnqParameters': {'hidden_layers': [100, 100, 100], 'nonlinearity': tf.nn.tanh}, 'learningParameters': {'discount': 0.75, 'learning_rate': 0.01, 'compress': False}, 'nnpParameters': {'hidden_layers': [10], 'nonlinearity': tf.nn.tanh}, 'nnvParameters': {'hidden_layers': [400], 'nonlinearity': tf.nn.relu}}}, [-25.250173550090494, -60024.22866212208, -999999, -26.234373688463325, -28.654420256839817]), ({'strat': {'lo': 0.5, 'hi': 1.5, 'max_iters': 40}, 'naf': {'nnqParameters': {'hidden_layers': [200], 'nonlinearity': tf.nn.relu}, 'learningParameters': {'discount': 0.94999999999999996, 'learning_rate': 0.002, 'compress': False}, 'nnpParameters': {'hidden_layers': [10], 'nonlinearity': tf.nn.tanh}, 'nnvParameters': {'hidden_layers': [200], 'nonlinearity': tf.nn.relu}}}, [-23.97603297758752, -22.91508380603151, -21.836824838489456, -20021.887743209976, -23.38939646751179]), ({'strat': {'lo': 0.5, 'hi': 1.7, 'max_iters': 40}, 'naf': {'nnqParameters': {'hidden_layers': [10, 10, 10], 'nonlinearity': tf.nn.tanh}, 'learningParameters': {'discount': 0.94999999999999996, 'learning_rate': 0.01, 'compress': False}, 'nnpParameters': {'hidden_layers': [5], 'nonlinearity': tf.nn.relu}, 'nnvParameters': {'hidden_layers': [10, 10, 10], 'nonlinearity': tf.nn.tanh}}}, [-31.383316244965325, -24.921037632405792, -31.996637068245615, -27.536028380980348, -20.372538741024858]), ({'strat': {'lo': 0.90000000000000002, 'hi': 1.1000000000000001, 'max_iters': 40}, 'naf': {'nnqParameters': {'hidden_layers': [400], 'nonlinearity': tf.nn.relu}, 'learningParameters': {'discount': 0.94999999999999996, 'learning_rate': 0.01, 'compress': False}, 'nnpParameters': {'hidden_layers': [25], 'nonlinearity': tf.nn.relu}, 'nnvParameters': {'hidden_layers': [100], 'nonlinearity': tf.nn.relu}}}, [-26.296388557582855, -20.89427613341008, -19.523615841063737, -20.602603609421536, -22.188776932197356]), ({'strat': {'lo': 0.69999999999999996, 'hi': 1.5, 'max_iters': 40}, 'naf': {'nnqParameters': {'hidden_layers': [5], 'nonlinearity': tf.nn.tanh}, 'learningParameters': {'discount': 0.98999999999999999, 'learning_rate': 0.002, 'compress': False}, 'nnpParameters': {'hidden_layers': [25], 'nonlinearity': tf.nn.tanh}, 'nnvParameters': {'hidden_layers': [50], 'nonlinearity': tf.nn.relu}}}, [-21.06601817784648, -23.15845622365715, -22.14261657425074, -22.754307461271633, -24.826766572102926]), ({'strat': {'lo': 0.5, 'hi': 1.5, 'max_iters': 40}, 'naf': {'nnqParameters': {'hidden_layers': [100, 100], 'nonlinearity': tf.nn.tanh}, 'learningParameters': {'discount': 0.94999999999999996, 'learning_rate': 0.001, 'compress': False}, 'nnpParameters': {'hidden_layers': [10], 'nonlinearity': tf.nn.relu}, 'nnvParameters': {'hidden_layers': [10, 10], 'nonlinearity': tf.nn.tanh}}}, [-22.941802315851337, -23.962775655281156, -20024.415603000027, -20.094943477830192, -22.356821797004105]), ({'strat': {'lo': 0.5, 'hi': 1.5, 'max_iters': 40}, 'naf': {'nnqParameters': {'hidden_layers': [100], 'nonlinearity': tf.nn.relu}, 'learningParameters': {'discount': 0.94999999999999996, 'learning_rate': 0.002, 'compress': False}, 'nnpParameters': {'hidden_layers': [10], 'nonlinearity': tf.nn.relu}, 'nnvParameters': {'hidden_layers': [200, 200], 'nonlinearity': tf.nn.tanh}}}, [-31.690895509856674, -21.211194389259408, -24.96813378505557, -23.226975669382654, -24.53260406899603]), ({'strat': {'lo': 0.90000000000000002, 'hi': 1.7, 'max_iters': 40}, 'naf': {'nnqParameters': {'hidden_layers': [100, 100, 100], 'nonlinearity': tf.nn.relu}, 'learningParameters': {'discount': 0.75, 'learning_rate': 0.001, 'compress': True}, 'nnpParameters': {'hidden_layers': [], 'nonlinearity': tf.nn.relu}, 'nnvParameters': {'hidden_layers': [1000], 'nonlinearity': tf.nn.tanh}}}, [-999999, -999999, -999999, -999999, -999999]), ({'strat': {'lo': 0.80000000000000004, 'hi': 1.7, 'max_iters': 40}, 'naf': {'nnqParameters': {'hidden_layers': [1000], 'nonlinearity': tf.nn.tanh}, 'learningParameters': {'discount': 0.75, 'learning_rate': 0.001, 'compress': True}, 'nnpParameters': {'hidden_layers': [], 'nonlinearity': tf.nn.tanh}, 'nnvParameters': {'hidden_layers': [400], 'nonlinearity': tf.nn.relu}}}, [-999999, -999999, -999999, -999999, -999999]), ({'strat': {'lo': 0.5, 'hi': 1.1000000000000001, 'max_iters': 40}, 'naf': {'nnqParameters': {'hidden_layers': [10], 'nonlinearity': tf.nn.tanh}, 'learningParameters': {'discount': 0.94999999999999996, 'learning_rate': 0.001, 'compress': True}, 'nnpParameters': {'hidden_layers': [5], 'nonlinearity': tf.nn.tanh}, 'nnvParameters': {'hidden_layers': [200], 'nonlinearity': tf.nn.tanh}}}, [-25.640008467080904, -19.384971229029453, -19.51565429452854, -19.36106611382076, -19.48931705402543]), ({'strat': {'lo': 0.90000000000000002, 'hi': 1.2, 'max_iters': 40}, 'naf': {'nnqParameters': {'hidden_layers': [200, 200], 'nonlinearity': tf.nn.relu}, 'learningParameters': {'discount': 0.98999999999999999, 'learning_rate': 0.002, 'compress': False}, 'nnpParameters': {'hidden_layers': [10], 'nonlinearity': tf.nn.relu}, 'nnvParameters': {'hidden_layers': [100, 100], 'nonlinearity': tf.nn.tanh}}}, [-999999, -999999, -160020.03119036145, -999999, -999999]), ({'strat': {'lo': 0.90000000000000002, 'hi': 1.5, 'max_iters': 40}, 'naf': {'nnqParameters': {'hidden_layers': [200, 200], 'nonlinearity': tf.nn.relu}, 'learningParameters': {'discount': 0.98999999999999999, 'learning_rate': 0.01, 'compress': True}, 'nnpParameters': {'hidden_layers': [10], 'nonlinearity': tf.nn.relu}, 'nnvParameters': {'hidden_layers': [200, 200], 'nonlinearity': tf.nn.relu}}}, [-999999, -999999, -999999, -999999, -999999]), ({'strat': {'lo': 0.69999999999999996, 'hi': 1.7, 'max_iters': 40}, 'naf': {'nnqParameters': {'hidden_layers': [10, 10, 10], 'nonlinearity': tf.nn.tanh}, 'learningParameters': {'discount': 0.94999999999999996, 'learning_rate': 0.0001, 'compress': True}, 'nnpParameters': {'hidden_layers': [25, 25], 'nonlinearity': tf.nn.relu}, 'nnvParameters': {'hidden_layers': [50], 'nonlinearity': tf.nn.relu}}}, [-999999, -26.501225508664028, -23.297874645410385, -999999, -19.362834214868233]), ({'strat': {'lo': 0.5, 'hi': 1.7, 'max_iters': 40}, 'naf': {'nnqParameters': {'hidden_layers': [400], 'nonlinearity': tf.nn.tanh}, 'learningParameters': {'discount': 0.98999999999999999, 'learning_rate': 0.001, 'compress': True}, 'nnpParameters': {'hidden_layers': [], 'nonlinearity': tf.nn.relu}, 'nnvParameters': {'hidden_layers': [100], 'nonlinearity': tf.nn.relu}}}, [-999999, -999999, -999999, -999999, -999999]), ({'strat': {'lo': 0.90000000000000002, 'hi': 1.2, 'max_iters': 40}, 'naf': {'nnqParameters': {'hidden_layers': [10], 'nonlinearity': tf.nn.tanh}, 'learningParameters': {'discount': 0.98999999999999999, 'learning_rate': 0.0001, 'compress': False}, 'nnpParameters': {'hidden_layers': [], 'nonlinearity': tf.nn.tanh}, 'nnvParameters': {'hidden_layers': [200, 200], 'nonlinearity': tf.nn.relu}}}, [-23.776477820350674, -27.317777999905765, -25.478292434689546, -25.447093736674724, -24.450355662759094]), ({'strat': {'lo': 0.5, 'hi': 1.2, 'max_iters': 40}, 'naf': {'nnqParameters': {'hidden_layers': [100, 100], 'nonlinearity': tf.nn.relu}, 'learningParameters': {'discount': 0.98999999999999999, 'learning_rate': 0.01, 'compress': True}, 'nnpParameters': {'hidden_layers': [10], 'nonlinearity': tf.nn.tanh}, 'nnvParameters': {'hidden_layers': [100, 100, 100], 'nonlinearity': tf.nn.relu}}}, [-999999, -999999, -999999, -999999, -999999])]

# %matplotlib inline

for r in sorted(results, key=lambda x: -1* np.average(x[1])):
    pprint.pprint(r[0])
    print(r[1])
    plt.hist(r[1])
    plt.show()
# Out:
# {'naf': {'learningParameters': {'compress': True,
#                                 'discount': 0.95,
#                                 'learning_rate': 0.001},
#          'nnpParameters': {'hidden_layers': [5],
#                            'nonlinearity': <function tanh at 0x7f2b363047d0>},
#          'nnqParameters': {'hidden_layers': [10],
#                            'nonlinearity': <function tanh at 0x7f2b363047d0>},
#          'nnvParameters': {'hidden_layers': [200],
#                            'nonlinearity': <function tanh at 0x7f2b363047d0>}},
#  'strat': {'hi': 1.1, 'lo': 0.5, 'max_iters': 40}}
# [-25.640008467080904, -19.384971229029453, -19.51565429452854, -19.36106611382076, -19.48931705402543]
# {'naf': {'learningParameters': {'compress': False,
#                                 'discount': 0.99,
#                                 'learning_rate': 0.01},
#          'nnpParameters': {'hidden_layers': [10],
# ...

# %%
import tensorflow as tf
from params import model
from qtable import naf
from policy import agent
from policy import samples
from envs.economy import jesusfv

'''
{'naf': {'learningParameters': {'compress': False,
                                'discount': 0.95,
                                'learning_rate': 0.01},
         'nnpParameters': {'hidden_layers': [25],
                           'nonlinearity': <function relu at 0x7f2b3616dde8>},
         'nnqParameters': {'hidden_layers': [400],
                           'nonlinearity': <function relu at 0x7f2b3616dde8>},
         'nnvParameters': {'hidden_layers': [100],
                           'nonlinearity': <function relu at 0x7f2b3616dde8>}},
 'strat': {'hi': 1.1, 'lo': 0.9, 'max_iters': 40}}
'''
params = {'naf': {'learningParameters': {'compress': True,
                                'discount': 0.99,
                                'learning_rate': 0.001},
         'nnpParameters': {'hidden_layers': [5],
                           'nonlinearity': tf.nn.tanh},
         'nnqParameters': {'hidden_layers': [10],
                           'nonlinearity': tf.nn.tanh},
         'nnvParameters': {'hidden_layers': [200],
                           'nonlinearity': tf.nn.tanh}},
 'strat': {'hi': 1.1, 'lo': 0.5, 'max_iters': 40}}
 

q = naf.SetupNAF.setup(jesusfv, **params['naf'])
memory = samples.Samples(10000)
a = agent.Agent(q, memory)

strat = agent.RelativeRangeStrat(**params['strat'])
for episode in range(500):
    print episode, a.episode(jesusfv, strat)
# Out:
# 0 5.29554482837
# 1 -1.74001042288
# 2 4.62892914634
# 3 2.03036308751
# 4 -0.0968306435866
# 5 0.902651953136
# 6 -0.250287627063
# 7 -1.11529285458
# 8 1.07337208767
# 9 0.149952014354
# 10 -2.44637723133
# 11 0.352507545097
# 12 -1.24276904924
# 13 -2.48808497755
# 14 -2.20349385303
# 15 1.17734784352
# 16 -2.33887753437
# 17 1.32655759153
# 18 -3.52640175209
# 19 1.22062316482
# 20 -6.33070420257
# 21 1.27700921855
# 22 -0.41570660181
# 23 -2.31716921386
# 24 -0.968106770842
# 25 -2.62354841507
# 26 -0.025766473623
# 27 -0.739090437257
# 28 1.34991490061
# 29 0.551920130627
# 30 -1.80220481913
# 31 -1.7655598171
# 32 2.20229204144
# 33 -1.16191685792
# 34 -1.04928928699
# 35 0.0119049672891
# 36 -0.780300046788
# 37 -0.764868732831
# 38 -1.83342194624
# 39 -2.46555973724
# 40 0.325953913546
# 41 -2.64440316358
# 42 -4.3373810508
# 43 0.200646497838
# 44 -3.64698019282
# 45 -0.0400002687248
# 46 -1.30670260131
# 47 0.445005362893
# 48 -4.97895705414
# 49 -4.80844133907
# ...

# %%
# %matplotlib inline


q.renderBestA()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-25-575a8455a59f> in <module>()
#       2
#       3
# ----> 4 q.renderBestA()
#
# /home/ygreif/bellmansrevenge/qtable/naf.pyc in renderBestA(self)
#     206         plt.plot([s[0] for s in x], best, label="best")
#     207         plt.title("Best Actions")
# --> 208         plt.waitforbuttonpress(0)
#     209         plt.close()
#     210
#
# /home/ygreif/bellmansrevenge/venv/local/lib/python2.7/site-packages/matplotlib/pyplot.pyc in waitforbuttonpress(*args, **kwargs)
#     724     If *timeout* is negative, does not timeout.
#     725     """
# --> 726     return gcf().waitforbuttonpress(*args, **kwargs)
#     727
#     728
#
# /home/ygreif/bellmansrevenge/venv/local/lib/python2.7/site-packages/matplotlib/figure.pyc in waitforbuttonpress(self, timeout)
#    1681
# ...

# %%
from envs.economy import jesusfv

state = model.sample_state()
reward = 0
q = a.qtable
for _ in range(200):
    max_prod = jesusfv.production.production(**state)
    action = q.action([samples.dict_to_tuple(state)], [(max_prod,)])[0]
    action = {'c': strat.explore(action, max_prod)}

    if action['c'] <= 0 or max_prod <= 0:
        print "fail"
        break

    utility, next_state = jesusfv.iterate(state, action)
    reward += utility
    print("state", state, "action", action, "next_state", next_state, "utility", utility, "max_prod", max_prod, "reward", reward)
    state = next_state
print reward
# Out:
# ('state', {'k': 0.032831708214613786, 'z': 0}, 'action', {'c': 0.072776550950477359}, 'next_state', {'k': 0.27360209573594529, 'z': 0}, 'utility', -2.6203614779942015, 'max_prod', 0.34637864668642265, 'reward', -2.6203614779942015)
# ('state', {'k': 0.27360209573594529, 'z': 0}, 'action', {'c': 0.16088645618427944}, 'next_state', {'k': 0.74840441743469133, 'z': 0}, 'utility', -1.8270564038885873, 'max_prod', 0.90929087361897076, 'reward', -4.447417881882789)
# ('state', {'k': 0.74840441743469133, 'z': 0}, 'action', {'c': 0.30466361216171389}, 'next_state', {'k': 1.332771697563373, 'z': 0}, 'utility', -1.1885470219737708, 'max_prod', 1.6374353097250869, 'reward', -5.63596490385656)
# ('state', {'k': 1.332771697563373, 'z': 0}, 'action', {'c': 1.133732871958969}, 'next_state', {'k': 1.276636532786221, 'z': 0}, 'utility', 0.12551561490991042, 'max_prod', 2.41036940474519, 'reward', -5.510449288946649)
# ...

# %%
print(a.episode(jesusfv, strat, train=False))
# Out:
# 1.68668055503
