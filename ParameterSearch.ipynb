# %%
# %load_ext autoreload
# %autoreload 2

# %%
import worker

results = worker.runworkers(num_params=10, max_iters=500, num_runs=5, max_workers=2)
# Out:
# params 1 attempt 0
# params 0 attempt 0
# WARNING actions did not converge
# [[ 0.92015028]
#  [ 0.7309919 ]
#  [ 0.79197425]
#  [ 0.73418611]
#  [ 0.91230565]
#  [ 0.735268  ]
#  [ 0.95070857]
#  [ 0.79892772]
#  [ 0.93254697]
#  [ 0.43191198]
#  [ 0.96771032]
#  [ 0.64388502]
#  [ 0.94564199]
#  [ 0.93834919]
#  [ 0.41417956]
#  [ 0.75222045]
#  [ 0.65137202]
#  [ 0.89247406]
#  [ 0.72918665]
#  [ 0.91816086]
#  [ 0.72223282]
#  [ 0.17239983]
#  [ 0.92978686]
#  [ 0.7828787 ]
#  [ 0.93805295]
#  [ 0.86885834]
#  [ 0.61538535]
#  [ 0.58894157]
#  [ 0.64791393]
#  [ 0.459786  ]
#  [ 0.40137976]
#  [ 0.76087838]
#  [ 0.92945063]
#  [ 0.87452149]
#  [ 0.82998884]
#  [ 0.44207186]
#  [ 0.28405964]
#  [ 0.39428881]
#  [ 0.32219037]
#  [ 0.83091962]
#  [ 0.80983871]
#  [ 0.75196499]
#  [ 0.71611428]
#  [ 0.69203889]
#  [ 0.74849391]
#  [ 0.95872474]
#  [ 0.80935144]
#  [ 0.88554561]
#  [ 0.67728442]
#  [ 0.86241728]
#  [ 0.26284578]
#  [ 0.5357818 ]
#  [ 0.59290642]
#  [ 0.72510141]
# ...

# %%
import matplotlib.pyplot as plt
import pprint

# %matplotlib inline

for r in results:
    pprint.pprint(r[0])
    plt.hist(r[1])
    plt.show()
# Out:
# {'naf': {'learningParameters': {'compress': False,
#                                 'discount': 0.75,
#                                 'learning_rate': 0.001},
#          'nnpParameters': {'hidden_layers': [25, 25],
#                            'nonlinearity': <function relu at 0x7f7ae3b8a398>},
#          'nnqParameters': {'hidden_layers': [10, 10],
#                            'nonlinearity': <function relu at 0x7f7ae3b8a398>},
#          'nnvParameters': {'hidden_layers': [10, 10],
#                            'nonlinearity': <function relu at 0x7f7ae3b8a398>}},
#  'strat': {'hi': 1.7, 'lo': 0.90000000000000002, 'max_iters': 40}}
# {'naf': {'learningParameters': {'compress': False,
#                                 'discount': 0.94999999999999996,
#                                 'learning_rate': 0.01},
#          'nnpParameters': {'hidden_layers': [],
#                            'nonlinearity': <function tanh at 0x7f7ae3d13cf8>},
# ...
